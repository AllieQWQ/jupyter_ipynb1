# %%
import csv
from selenium import webdriver
from selenium.webdriver.common.by import By
driver_path = "D:\\Anaconda\\Scripts\\MicrosoftWebDriver.exe"
driver = webdriver.Edge()
driver.get('https://www.douban.com')

li_list = driver.find_elements(By.XPATH,'//div/div[2]/div/div/ol/li')
print(li_list)
with open('./data.csv','a+',encoding='utf-8',newline='') as f:
    f_csv = csv.writer(f)
    f_csv.writerow(['电影名称'])
    for i in li_list:
        movie_name = i.find_element(By.TAG_NAME, 'a').text
        f_csv.writerow([movie_name])
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a9bcc37f0e2f5779966d643bc2ee8fbb", element="f.F56C75D58CE6574285544C956458F8AE.d.827A50525182915A27B5FBFBF8E63830.e.38")>, <selenium.webdriver.remote.webelement.WebElement (session="a9bcc37f0e2f5779966d643bc2ee8fbb", element="f.F56C75D58CE6574285544C956458F8AE.d.827A50525182915A27B5FBFBF8E63830.e.39")>, <selenium.webdriver.remote.webelement.WebElement (session="a9bcc37f0e2f5779966d643bc2ee8fbb", element="f.F56C75D58CE6574285544C956458F8AE.d.827A50525182915A27B5FBFBF8E63830.e.40")>, <selenium.webdriver.remote.webelement.WebElement (session="a9bcc37f0e2f5779966d643bc2ee8fbb", element="f.F56C75D58CE6574285544C956458F8AE.d.827A50525182915A27B5FBFBF8E63830.e.41")>, <selenium.webdriver.remote.webelement.WebElement (session="a9bcc37f0e2f5779966d643bc2ee8fbb", element="f.F56C75D58CE6574285544C956458F8AE.d.827A50525182915A27B5FBFBF8E63830.e.42")>, <selenium.webdriver.remote.webelement.WebElement (session="a9bcc37f0e2f5779966d643bc2ee
# ...

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By
wd=webdriver.Edge(service=Service('D:\\Anaconda\\Scripts\\MicrosoftWebDriver.exe'))
wd.get('http://www.douban.com')
try:
    divElement=wd.find_element(By.XPATH,'//*[@id="anony-movie"]/div/div[1]')
    print(divElement)
    d1=divElement.get_property('outerHTML')
    print(d1)
    d2=divElement.get_property('innerHTML')
    print(d2)
except Exception:
    print("没找到符合条件的标签")
List=wd.find_elements(By.XPATH,'//*[@class="list1 movie-charts"]/ol/li')
for i in List:
    print(i.get_property('outerHTML'))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="961981ce5b9a51057f83eafc0e71575d", element="f.F088801A7A67E7D50F3CC422B968A00D.d.AA3167BA2ABBCD7BE911DA8E85755CF2.e.60")>
# <div class="sidenav">
#   <h2 class="section-title"><a href="https://movie.douban.com">电影</a></h2>
#
#
#   <div class="side-links nav-anon">
#       <ul>
#
#                  <li><a href="https://movie.douban.com/nowplaying/">影讯&amp;购票</a></li>
#
#                  <li class="site-nav-bt"><a href="https://movie.douban.com/explore">选电影</a></li>
#
#                  <li><a href="https://movie.douban.com/tv/">电视剧</a></li>
#
#                  <li><a href="https://movie.douban.com/chart">排行榜</a></li>
#
#                  <li><a href="https://movie.douban.com/review/best/">影评</a></li>
#
#
#       </ul>
#   </div>
#
#
#
#
#     <div class="apps-list">
#     <ul>
#     </ul>
#     </div>
#
# </div>
#
#   <h2 class="section-title"><a href="https://movie.douban.com">电影</a></h2>
#
#
# ...
