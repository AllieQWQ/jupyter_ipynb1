# %%
import csv
import requests
from bs4 import BeautifulSoup



def get_one_page(url):
    header = {
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0',
        'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'cookie':'e1=%7B%22l6%22%3A%22%22%2C%22l7%22%3A%22%22%2C%22l1%22%3A5%2C%22l3%22%3A%22%22%2C%22pid%22%3A%22qd_P_rank_18%22%2C%22eid%22%3A%22%22%7D; e2=%7B%22l6%22%3A%22%22%2C%22l7%22%3A%22%22%2C%22l1%22%3A5%2C%22l3%22%3A%22%22%2C%22pid%22%3A%22qd_P_rank_18%22%2C%22eid%22%3A%22%22%7D; newstatisticUUID=1740971602_812026477; _csrfToken=hrU9EQClMLJBTHGN73rpOT2ea6Hg6p5muhDatyCS; fu=714612888; traffic_utm_referer=https%3A//cn.bing.com/; Hm_lvt_f00f67093ce2f38f215010b699629083=1740971605; HMACCOUNT=CAB7838FAA72C292; _gid=GA1.2.790839401.1740971606; supportwebp=true; _ga_FZMMH98S83=GS1.1.1740971606.1.1.1740972807.0.0.0; _ga=GA1.1.1103195342.1740971606; _ga_PFYW0QLV3P=GS1.1.1740971606.1.1.1740972807.0.0.0; Hm_lpvt_f00f67093ce2f38f215010b699629083=1740972807; w_tsfp=ltvuV0MF2utBvS0Q7argk0iuEjAkfT84h0wpEaR0f5thQLErU5mB0Y99vcvzOHbX5cxnvd7DsZoyJTLYCJI3dwNGRJrDIYgRiwTBlogmjYYRUERgGJ3ZDFQZcOgk5DEXKXhCNxS00jA8eIUd379yilkMsyN1zap3TO14fstJ019E6KDQmI5uDW3HlFWQRzaLbjcMcuqPr6g18L5a5Tvc5VrzfVhwUbJH1xbHh30ZXH8q4BLqIbxaN0+vI8/7SqA=',
        'accept-encoding':'gzip, deflate, br, zstd'
    }
    r = requests.get(url,headers=header)
    r.encoding = r.apparent_encoding  # 设置编码格式
    demo = r.text
    return demo


def parse_one_page(html):
    soup = BeautifulSoup(html,'html.parser')
    Books = soup.select('#book-img-text > ul > li')

    #Book_data = []
    for book in Books:
        Book_name = book.select('div.book-mid-info > h2 > a')[0].string
        Book_writer = book.select('div.book-mid-info > p.author > a.name')[0].string
        Book_introduce = book.select('div.book-mid-info > p.intro')[0].string
        Book_time = book.select('div.book-mid-info > p.update > span')[0].string
        #Book_data.append([Book_name,Book_writer,Book_introduce,Book_time])
    #return Book_data
        #print(Book_name,Book_writer,Book_introduce,Book_time)
    
    
    #字典的形式进行迭代器
        bookQ = {
            'Book_name':Book_name,
            'Book_Writer':Book_writer,
            'Book_intro':Book_introduce,
            'Book_time':Book_time
        }
        yield bookQ
        print(bookQ)
    

def write_to_csv(content):
    with open('book.csv','w',encoding='utf-8-sig',newline='')as f:
        writer = csv.writer(f)
        



if __name__ == '__main__':
    url = 'https://www.qidian.com/rank/readindex/'
    html = get_one_page(url)
    #print(html)
    content = parse_one_page(html)
    write_to_csv(content)
# Out:
# <!doctype html><html data-theme="default"><script type="text/javascript" src="/C2WF946J0/probev3.js" r='m'></script>  <head> <script async src="https://turing.captcha.qcloud.com/TCaptcha.js"></script><script>try{var name="x-waf-captcha-referer",reg=new RegExp("(^| )"+name+"=([^;]*)(;|$)"),wafReferer=document.cookie.match(reg);wafReferer&&wafReferer[2]&&(Object.defineProperty(document,"referrer",{value:decodeURIComponent(wafReferer[2])}),document.cookie=name+"=;path=/;expires=Thu, 01-Jan-1970 00:00:01 GMT")}catch(e){console.log(e)}</script><script>var name="seo-jump-referrer";try{var reg=new RegExp("(^| )"+name+"=([^;]*)(;|$)"),seoReferer=document.cookie.match(reg);seoReferer&&seoReferer[2]&&(Object.defineProperty(document,"referrer",{value:decodeURIComponent(seoReferer[2])}),document.cookie=name+"=;domain=.qidian.com;path=/;expires=Thu, 01-Jan-1970 00:00:01 GMT")}catch(a){console.log(a)}if(window.outerWidth<=1024&&navigator.userAgent.match(/(Android|iPhone|SymbianOS|Windows Phone|iPa
# ...
