# %%
import csv
import requests
from bs4 import BeautifulSoup

def get_one_page(url):
    header = {
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0',
        'cookie':'kg_mid=183f92c43bac1779b5b88e5d8d210f3d; ACK_SERVER_10015=%7B%22list%22%3A%5B%5B%22gzlogin-user.kugou.com%22%5D%5D%7D; kg_dfid=11RmS2259yx01x8LyB0zcmJK; kg_dfid_collect=d41d8cd98f00b204e9800998ecf8427e; Hm_lvt_aedee6983d4cfc62f509129360d6bb3d=1741245285; HMACCOUNT=43A925589B8B1300; Hm_lpvt_aedee6983d4cfc62f509129360d6bb3d=1741245295',
        'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7'
    }
    r = requests.get(url,headers=header)
    r.encoding = r.apparent_encoding  # 设置编码格式
    demo = r.text
    return demo


def parse_one_page(html):
    soup = BeautifulSoup(html,'html.parser')
    Songs = soup.select('#rankWrap > div.pc_temp_songlist > ul > li')

    Song_data = []
    #遍历每一首歌曲li节点
    for song in Songs:
        
        song_rank = song.find('span',class_="pc_temp_num").text.strip()    #歌曲排名
        
        singer_and_name = song.select('a')[0]['title'].split('-')  
        
        singer = singer_and_name[0].strip()     
        song_name = singer_and_name[1].strip()

        
        song_time = song.find('span',class_ ="pc_temp_time").text.strip()
        
        Song_data.append([song_rank,singer,song_name,song_time]) 
        
        print(song_rank,singer,song_name,song_time)
    return Song_data



    


def write_to_csv(content,path):
    with open(path,'a', newline='', encoding='utf-8-sig') as csvfile:
        writer = csv.writer(csvfile)
        #writer.writerow(['排名','歌手','歌曲','时长'])  # 写入表头
        writer.writerows(content)  # 写入数据


if __name__ == '__main__':
    for i in range(1,11):
        if i == 1:
            url = 'https://www.kugou.com/yy/rank/home/1-8888.html?from=rank'
        else:
            url = f'https://www.kugou.com/yy/rank/home/{i}-8888.html?from=rank'
        html = get_one_page(url)
        #print(html)
        content = parse_one_page(html)
    
        write_to_csv(content,'singer.csv')
# Out:
# 1 LBI利比（时柏尘） 跳楼机 3:21
# 2 马健涛 搀扶 5:27
# 3 G.E.M. 邓紫棋 唯一 4:13
# 4 方大同 特别的人 4:19
# 5 李秉成 只为你着迷 4:00
# 6 于冬然 座位 3:28
# 7 小璐 平凡日子里的挣扎 3:23
# 8 EXO Baby, Don't Cry (人鱼的眼泪)(Chinese Ver.) 3:55
# 9 Valentin Unchanged Mind 5:07
# 10 王唯旖 舍得 4:22
# 11 唐汉霄 就是哪吒 3:51
# 12 李雨婷 烟火里的尘埃 (我的心里住着一个苍老的小孩) 5:26
# 13 蔡健雅 越来越不懂 4:09
# 14 Muyoi、Pezzi 一点 3:20
# 15 郑润泽 瞬 4:44
# 16 大双二双 说书人 (说不完这人间沧桑) 3:40
# 17 田园 先说爱的人为什么先离开 3:40
# 18 刘晓超 不能不想你 4:09
# 19 方大同 麦恩莉 4:48
# 20 马健涛 你本来就很美 3:07
# 21 王菲 世界赠予我的 4:04
# 22 卢润泽 土坡上的狗尾草 3:16
# 23 陶喆 爱我还是他 4:52
# 24 王力宏 爱错 3:58
# 25 郭静 下一个天亮 4:26
# 26 邓典 伤心剖半 (把你的心剖开来) 2:51
# 27 孙燕姿 我怀念的 4:49
# 28 容祖儿 没关系 3:40
# 29 yihuik苡慧 有些 3:41
# 30 陈奕迅 孤独患者 4:33
# 31 邵甲天 ET、无面小生、口古口古、Happer 我爱你但是我要回家 3:14
# 32 诺爷Plus 就让冷风吹 3:27
# 33 方大同 爱爱爱 3:33
# 34 杨乃文 推开世界的门 4:42
# 35 方大同 Love Song 4:29
# 36 艾比利 一个人想着一个人 (说唱版) 3:09
# 37 王睿卓 大山 3:39
# 38 马健涛 童年老家 5:42
# 39 杨丞琳 雨爱 4:20
# 40 陈瑞 情罪 4:45
# 41 魏玉慧 相思遥 3:13
# 42 汪苏泷 像晴天像雨天 3:56
# 43 音乐磁场 我记得你眼里的依恋 4:26
# 44 吕艳婷、瀚墨 我乃哪吒三太子 3:12
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup
import os

def get_one_page(url):
    header = {
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0',
        'cookie':'kg_mid=183f92c43bac1779b5b88e5d8d210f3d; ACK_SERVER_10015=%7B%22list%22%3A%5B%5B%22gzlogin-user.kugou.com%22%5D%5D%7D; kg_dfid=11RmS2259yx01x8LyB0zcmJK; kg_dfid_collect=d41d8cd98f00b204e9800998ecf8427e; Hm_lvt_aedee6983d4cfc62f509129360d6bb3d=1741245285; HMACCOUNT=43A925589B8B1300; Hm_lpvt_aedee6983d4cfc62f509129360d6bb3d=1741245295',
        'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7'
    }
    r = requests.get(url,headers=header)
    r.encoding = r.apparent_encoding  # 设置编码格式
    demo = r.text
    return demo


def parse_one_page(html):
    soup = BeautifulSoup(html,'html.parser')
    Songs = soup.select('#rankWrap > div.pc_temp_songlist > ul > li')

    Song_data = []
    #遍历每一首歌曲li节点
    for song in Songs:
        
        song_rank = song.find('span',class_="pc_temp_num").text.strip()    #歌曲排名
        
        singer_and_name = song.select('a')[0]['title'].split('-')  
        
        singer = singer_and_name[0].strip()     
        song_name = singer_and_name[1].strip()

        
        song_time = song.find('span',class_ ="pc_temp_time").text.strip()
        
        Song_data.append([song_rank,singer,song_name,song_time]) 
        
        print(song_rank,singer,song_name,song_time)
    return Song_data



    


def write_to_csv(content,path):
    file_exists = os.path.isfile(path)
    with open(path, 'a', newline='', encoding='utf-8-sig') as csvfile:
        writer = csv.writer(csvfile)
        
        if not file_exists:
            writer.writerow(['排名', '歌手', '歌曲', '时长'])
        writer.writerows(content)  # 写入数据


if __name__ == '__main__':
    for i in range(1,16):
        if i == 1:
            url = 'https://www.kugou.com/yy/rank/home/1-8888.html?from=rank'
        else:
            url = f'https://www.kugou.com/yy/rank/home/{i}-8888.html?from=rank'
        html = get_one_page(url)
        #print(html)
        content = parse_one_page(html)
    
        write_to_csv(content,'singer.csv')
# Out:
# 1 LBI利比（时柏尘） 跳楼机 3:21
# 2 马健涛 搀扶 5:27
# 3 G.E.M. 邓紫棋 唯一 4:13
# 4 方大同 特别的人 4:19
# 5 李秉成 只为你着迷 4:00
# 6 于冬然 座位 3:28
# 7 小璐 平凡日子里的挣扎 3:23
# 8 EXO Baby, Don't Cry (人鱼的眼泪)(Chinese Ver.) 3:55
# 9 Valentin Unchanged Mind 5:07
# 10 王唯旖 舍得 4:22
# 11 唐汉霄 就是哪吒 3:51
# 12 李雨婷 烟火里的尘埃 (我的心里住着一个苍老的小孩) 5:26
# 13 蔡健雅 越来越不懂 4:09
# 14 Muyoi、Pezzi 一点 3:20
# 15 郑润泽 瞬 4:44
# 16 大双二双 说书人 (说不完这人间沧桑) 3:40
# 17 田园 先说爱的人为什么先离开 3:40
# 18 刘晓超 不能不想你 4:09
# 19 方大同 麦恩莉 4:48
# 20 马健涛 你本来就很美 3:07
# 21 王菲 世界赠予我的 4:04
# 22 卢润泽 土坡上的狗尾草 3:16
# 23 陶喆 爱我还是他 4:52
# 24 王力宏 爱错 3:58
# 25 郭静 下一个天亮 4:26
# 26 邓典 伤心剖半 (把你的心剖开来) 2:51
# 27 孙燕姿 我怀念的 4:49
# 28 容祖儿 没关系 3:40
# 29 yihuik苡慧 有些 3:41
# 30 陈奕迅 孤独患者 4:33
# 31 邵甲天 ET、无面小生、口古口古、Happer 我爱你但是我要回家 3:14
# 32 诺爷Plus 就让冷风吹 3:27
# 33 方大同 爱爱爱 3:33
# 34 杨乃文 推开世界的门 4:42
# 35 方大同 Love Song 4:29
# 36 艾比利 一个人想着一个人 (说唱版) 3:09
# 37 王睿卓 大山 3:39
# 38 马健涛 童年老家 5:42
# 39 杨丞琳 雨爱 4:20
# 40 陈瑞 情罪 4:45
# 41 魏玉慧 相思遥 3:13
# 42 汪苏泷 像晴天像雨天 3:56
# 43 音乐磁场 我记得你眼里的依恋 4:26
# 44 吕艳婷、瀚墨 我乃哪吒三太子 3:12
# ...
